# %% [markdown]
# ## Step 1: Install and Import Matplotlib
#
# **Installation (only once)**
#
# If you haven't already installed it:

# %%
pip install matplotlib

# %% [markdown]
# **Importing the Library**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# pyplot is a module in matplotlib that provides a MATLAB-like interface — think of it as your graph drawing toolbox.

# %% [markdown]
# ## Step 2: Your First Basic Plot
#
# **Example: Plotting a Line**

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)        # Plot the graph
plt.title("Basic Line Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation:**
#
# * x and y: These are lists of coordinates.
# * plt.plot(): Plots the graph (by default, a line).
# * plt.title(), plt.xlabel(), plt.ylabel(): Add context.
# * plt.grid(True): Adds a grid.
# * plt.show(): Renders the graph window.

# %% [markdown]
# ## Step 3: Plot Multiple Lines
#
# **Example:**

# %%
x = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
y2 = [5, 15, 20, 22]

plt.plot(x, y1, label="Model A")
plt.plot(x, y2, label="Model B")

plt.title("Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Tip for ML:**
#
# Use this method to compare training vs validation accuracy, or multiple model results.

# %% [markdown]
# ## Step 4: Add Style

# %%
plt.plot(x, y1, color='blue', linestyle='--', marker='o', label="Training")
plt.plot(x, y2, color='green', linestyle='-', marker='x', label="Validation")

# %% [markdown]
# | Parameter | Usage |
# | --- | --- |
# | color | 'red', 'blue', '#00FF00' |
# | linestyle | '-', '--', '-.', ':' |
# | marker | 'o', 's', '^', 'x', 'D' |

# %% [markdown]
# ## Step 5: Set Axis Range

# %%
plt.axis([0, 5, 0, 35])  # [xmin, xmax, ymin, ymax]
# Out:
# (0.0, 5.0, 0.0, 35.0)

# %% [markdown]
# Useful when you want to focus on a specific data range.

# %% [markdown]
# ## Step 6: Save the Graph as Image

# %%
plt.savefig("myplot.png", dpi=300)

# %% [markdown]
# Great for documentation or presentations.

# %% [markdown]
# ## Step 7: Bar Charts (Useful for Feature Importance)

# %%
features = ['Feature A', 'Feature B', 'Feature C']
importance = [0.3, 0.5, 0.2]

plt.bar(features, importance, color='skyblue')
plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()

# %% [markdown]
# ## Step 8: Scatter Plots (Good for Visualizing Clusters)

# %%
x = [1, 2, 3, 4]
y = [10, 15, 13, 18]

plt.scatter(x, y, color='purple', marker='x')
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# Use this when visualizing data distribution, k-means clusters, etc.

# %% [markdown]
# ## Step 9: Subplots (Multiple Plots in One Figure)

# %%
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2, 1, 1)  # (rows, cols, index)
plt.plot(x, y1)
plt.title("Sine Function")

plt.subplot(2, 1, 2)
plt.plot(x, y2)
plt.title("Cosine Function")

plt.tight_layout()
plt.show()

# %% [markdown]
# Subplots are ideal when you want to compare functions or results visually.

# %% [markdown]
# ## Step 10: Plotting From Pandas (For ML Workflows)

# %%
import pandas as pd

data = {
    'epoch': [1, 2, 3, 4],
    'train_accuracy': [0.6, 0.7, 0.8, 0.85],
    'val_accuracy': [0.58, 0.68, 0.75, 0.8]
}

df = pd.DataFrame(data)

plt.plot(df['epoch'], df['train_accuracy'], label='Training')
plt.plot(df['epoch'], df['val_accuracy'], label='Validation')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Real machine learning projects are usually built on Pandas DataFrames.

# %% [markdown]
# ## Show Value on Bar Chart

# %%
for i, v in enumerate(importance):
    plt.text(i, v + 0.01, str(v), ha='center')

plt.bar(features, importance)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Use Cases in Machine Learning
#
# | Task | Visualization Tip |
# | --- | --- |
# | Model Training | Line Plot (accuracy/loss) |
# | Feature Importance | Bar Chart |
# | Clustering | Scatter Plot |
# | Subset Comparison | Subplots |
